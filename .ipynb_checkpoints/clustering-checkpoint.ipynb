# %% [markdown]
# # Clustering usando PCA y K-Means

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
df =  pd.read_parquet('logs.parquet')

# %% [markdown]
# ## Comportamiento de los usuarios
#
# Para poder analizar el comportamiento de los usuarios voy a agruparlos para poder obtener diferentes metricas como son: `TotalEventos`, `DuracionTotal`, `DiseñosUnicos`, `PiezasUnicas` y `CatalogosUnicos`.

# %%
usuarios = df.groupby('Usuario')
userdf = pd.DataFrame()
userdf['TotalEventos'] = usuarios.size()
userdf['DuracionTotal'] = usuarios['minutos'].sum()
userdf['DiseñosUnicos'] = usuarios.apply(
        lambda x: x.loc[x['diseñoid'].notna(), 'diseñoid'].nunique(),
        include_groups=False
    )
userdf['PiezasUnicas'] = usuarios.apply(
        lambda x: x.loc[x['Evento'] == 'AÑADIR_PIEZA', 'pieza'].nunique(),
        include_groups=False
    )
userdf['CatalogosUnicos'] = usuarios.apply(
        lambda x: x.loc[x['Evento'] == 'AÑADIR_PIEZA', 'catalogo'].nunique(),
        include_groups=False
    )

userdf.fillna(0, inplace=True) 
userdf
# Out:
#                                 TotalEventos  DuracionTotal  DiseñosUnicos  \
# Usuario
# #0 - null                             325347       0.000000             81
# #1002 - MOBIHOGAR                       4058   40081.046875            121
# #10025 - MUEBLES MESEGUER S.L.             8     122.596603              0
# #10030 - HOGAR MOBLE N1                   46     485.475037              2
# #1005 - JESUS BERLANGA HERMOSO           804    3973.846680             24
# ...                                      ...            ...            ...
# #985 - MUEBLES PEREZ                      73     755.824524              8
# #987 - BELEN Y VALLE                       4      60.917915              0
# #989 - MUEBLES JULIAN MIGUEL             344    3362.233643             13
# #990 - MORGAR DECORACION. S.L.            16     278.941315              0
# #991 - MUEBLES AVENIDA                     3      62.560268              0
#
#                                 PiezasUnicas  CatalogosUnicos
# Usuario
# #0 - null                                  0                0
# #1002 - MOBIHOGAR                        830               24
# #10025 - MUEBLES MESEGUER S.L.             0                0
# #10030 - HOGAR MOBLE N1                    9                3
# #1005 - JESUS BERLANGA HERMOSO           197                7
# ...                                      ...              ...
# #985 - MUEBLES PEREZ                      13                2
# #987 - BELEN Y VALLE                       0                0
# #989 - MUEBLES JULIAN MIGUEL              58                4
# #990 - MORGAR DECORACION. S.L.             0                0
# #991 - MUEBLES AVENIDA                     0                0
#
# [3099 rows x 5 columns]

# %% [markdown]
# ## Correlación entre variables
#
# Para tener un mejor análisis quito el usuario null, que como acabamos de observar es el que más eventos tiene, ya que registra los eventos de CONEXION y DESCONEXION.

# %%
userdf = userdf.drop(index='#0 - null')
correlacion_user = userdf.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlacion_user, annot=True, cmap='coolwarm', center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Matriz de correlaciones entre variables de usuarios')
# Out:
# Text(0.5, 1.0, 'Matriz de correlaciones entre variables de usuarios')

# %% [markdown]
# Podemos observar que las variables que hemos agrupados esta muy correlacionadas entre ellas, teniendo una correlacion > 0,6 en todas ellas.
#
# ## Estandarización y Reducción de Dimensiones con PCA
#
# Aplico `StandardScarler()` sobre mis variables para estandarizar los datos para que todos tengan una escala común, para que unos datos no predominen sobre otros.

# %%
scaler = StandardScaler()
userdf[['TotalEventos_T', 'DuracionTotal_T','DiseñosUnicos_T', 'PiezasUnicas_T','CatalogosUnicos_T']] = scaler.fit_transform(userdf)
pca = PCA(n_components=2)
pcadf = pca.fit_transform(userdf[['TotalEventos_T', 'DuracionTotal_T','DiseñosUnicos_T', 'PiezasUnicas_T','CatalogosUnicos_T']])
userdf[['PC1', 'PC2']] = pcadf
userdf.head()
# Out:
#                                 TotalEventos  DuracionTotal  DiseñosUnicos  \
# Usuario
# #1002 - MOBIHOGAR                       4058   40081.046875            121
# #10025 - MUEBLES MESEGUER S.L.             8     122.596603              0
# #10030 - HOGAR MOBLE N1                   46     485.475037              2
# #1005 - JESUS BERLANGA HERMOSO           804    3973.846680             24
# #10058 - ARUMA MOBEL S.L.                 57     587.975098              2
#
#                                 PiezasUnicas  CatalogosUnicos  TotalEventos_T  \
# Usuario
# #1002 - MOBIHOGAR                        830               24        2.062889
# #10025 - MUEBLES MESEGUER S.L.             0                0       -0.314202
# #10030 - HOGAR MOBLE N1                    9                3       -0.291898
# #1005 - JESUS BERLANGA HERMOSO           197                7        0.152999
# #10058 - ARUMA MOBEL S.L.                 21                4       -0.285442
#
#                                 DuracionTotal_T  DiseñosUnicos_T  \
# Usuario
# #1002 - MOBIHOGAR                      2.527564         2.213471
# #10025 - MUEBLES MESEGUER S.L.        -0.320895        -0.333454
# #10030 - HOGAR MOBLE N1               -0.295027        -0.291356
# #1005 - JESUS BERLANGA HERMOSO        -0.046357         0.171721
# #10058 - ARUMA MOBEL S.L.             -0.287720        -0.291356
#
#                                 PiezasUnicas_T  CatalogosUnicos_T       PC1  \
# Usuario
# #1002 - MOBIHOGAR                     3.000750           3.216967  5.762058
# #10025 - MUEBLES MESEGUER S.L.       -0.411114          -0.652323 -0.887506
# #10030 - HOGAR MOBLE N1              -0.374118          -0.168662 -0.643679
# #1005 - JESUS BERLANGA HERMOSO        0.398690           0.476220  0.498999
# #10058 - ARUMA MOBEL S.L.            -0.324790          -0.007442 -0.552480
#
#                                      PC2
# Usuario
# #1002 - MOBIHOGAR               1.219703
# #10025 - MUEBLES MESEGUER S.L. -0.342625
# #10030 - HOGAR MOBLE N1         0.062787
# #1005 - JESUS BERLANGA HERMOSO  0.358892
# #10058 - ARUMA MOBEL S.L.       0.204831

# %% [markdown]
# ## Optimización de Número de Clústers

# %%
def optimise_k_means(data, max_k):
    means = []
    inertias = []

    for k in range(1, max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(data)

        means.append(k)
        inertias.append(kmeans.inertia_)
    plt.subplots(figsize = (10, 5))
    plt.plot(means, inertias, 'o-')
    plt.show()

# %%
optimise_k_means(userdf[['PC1', 'PC2']], 10)

# %% [markdown]
# ## Algoritmo K-Means
#
# A partir de la observacion anterior podemos concluir que 3 clusters son suficientes para representar a los grupos de usuarios.

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(userdf[['PC1','PC2']])
userdf['kmeans_pca'] = kmeans.labels_

# %%
plt.scatter(x=userdf.PC1, y=userdf.PC2, c=userdf.kmeans_pca)
plt.show()

# %% [markdown]
# ## Evaluación del Clustering

# %%
print("Contribucion de cada componente:", pca.explained_variance_ratio_)
# Out:
# Contribucion de cada componente: [0.86274307 0.09301998]

# %% [markdown]
# El `silhouette_score` es una medida que nos indica como de bien se han agrupado los datos, teniendo en cuenta la distancia de un punto con los demás puntos de su grupo y la distancia al grupo vecino más cercano.

# %%
silhouette_avg = silhouette_score(userdf[['PC1', 'PC2']], userdf['kmeans_pca'])
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.7862570795559681

# %% [markdown]
# - Silhouette Score: +1. Indica que los clusters estan perfectamente agrupados.
#
# - Silhouette Score: 0. Indica que hay solapamiento y es difícil distinguir entre dos grupos.
#
# - Silhouette Score: -1. Indica que los puntos están más cercanos a otro grupo que al suyo mismo.
